# %% [markdown]
# # Homework 1
# In this homework, we will have you train some convolutional neural networks! We will start with a small dataset, and then work our way up to ImageNet!
#
# For this homework we will train a classifier for Tiny Imagenet which you can read about here https://tiny-imagenet.herokuapp.com/ but don't bother downloading it just yet.
#
# A note on file paths: Last homework, we used the homework1 folder. That was a mistake as it was technically homework 0. You may want to rename the folder from last time to homework0 before you begin.
#
# # Part 0: Initial Setup
# You should recognize this code from last time.

# %%
# This is code to download and install pytorch
import os
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if os.path.exists('/opt/bin/nvidia-smi') else 'cpu'
# !pip install http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision

import torch
print('Version', torch.__version__)
print('CUDA enabled:', torch.cuda.is_available())
# Out:
# Collecting torch==0.4.1 from http://download.pytorch.org/whl/cu80/torch-0.4.1-cp36-cp36m-linux_x86_64.whl
#   Downloading http://download.pytorch.org/whl/cu80/torch-0.4.1-cp36-cp36m-linux_x86_64.whl (483.0MB)
#     100% |████████████████████████████████| 483.0MB 52.8MB/s
# tcmalloc: large alloc 1073750016 bytes == 0x55f9e000 @  0x7f80263982a4 0x594e17 0x626104 0x51190a 0x4f5277 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f6070 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f6070 0x4f3338 0x510fb0 0x5119bd 0x4f6070
# Collecting torchvision
#   Downloading https://files.pythonhosted.org/packages/ca/0d/f00b2885711e08bd71242ebe7b96561e6f6d01fdb4b9dcf4d37e2e13c5e1/torchvision-0.2.1-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 2.4MB/s
# Collecting pillow>=4.1.1 (from torchvision)
#   Downloading https://files.pythonhosted.org/packages/62/94/5430ebaa83f91cc7a9f687ff5238e26164a779cca2ef9903232268b0a318/Pillow-5.3.0-cp36-cp36m-manylinux1_x86_64.whl (2.0MB)
#     100% |████████████████████████████████| 2.0MB 5.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.14.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.11.0)
# Installing collected packages: torch, pillow, torchvision
#   Found existing installation: Pillow 4.0.0
#     Uninstalling Pillow-4.0.0:
#       Successfully uninstalled Pillow-4.0.0
# Successfully installed pillow-5.3.0 torch-0.4.1 torchvision-0.2.1
# Version 0.4.1
# CUDA enabled: True

# %%
from google.colab import drive
drive.mount('/gdrive')
# !ls /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# 'My Drive'  'Team Drives'

# %% [markdown]
# # Part 1: Upload the Dataset
# Run this code to navigate to the BASE_PATH directory and upload the homework1.tar file inside the BASE_PATH, then extract it.
#
# Have a look at pt_util. We moved some of the useful functions out of the python notebook to make it less cluttered, and added a few more useful functions.
#
# I made the BASE_PATH and DATA_PATH variables so you don't have to copy the same strings all over the place if you want to move the locations of the files around.

# %%
BASE_PATH = '/gdrive/My Drive/colab_files/homework1/'
if not os.path.exists(BASE_PATH):
    os.makedirs(BASE_PATH)
DATA_PATH = BASE_PATH + 'tiny_imagenet/'

# !pwd
# !ls
os.chdir(BASE_PATH)
if not os.path.exists(DATA_PATH + 'train.h5'):
    # !wget http://pjreddie.com/media/files/homework1.tar
    # !tar -xvf homework1.tar
    # !rm homework1.tar
os.chdir('/content')
# Out:
# /content
# sample_data

# %%
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
import h5py
import sys
sys.path.append(BASE_PATH)
import pt_util

# %% [markdown]
# # Part 2: Defining the Network
# We're giving you no instructions on this part. Welcome to deep learning research! See if you can get above 40% accuracy. You probably want to use the Cross Entropy error again, but who knows, maybe you can find a better loss function. We will give you a few hints of things to try. Have a look at https://github.com/pytorch/examples/blob/master/mnist/main.py for a basic neural network implementation.
#
#
# - Activation functions other than ReLU
# - Batch Norm
# - Dropout
# - Residual connections
#
# Additionally, the current saving function always saves the latest results. You may want to modify it to only save the results if they have the highest test accuracy. Please make this modification.

# %%
class InceptionModule(nn.Module):
    def __init__(self, in_chan, out_chan):
      super(InceptionModule, self).__init__()

      self.conv1 = nn.Conv2d(in_chan, int(in_chan / 2), padding=0, kernel_size=1, stride=1)
      self.bn1 = nn.BatchNorm2d(int(in_chan / 2))
      self.conv2 = nn.Conv2d(int(in_chan / 2), out_chan, padding=1, kernel_size=3, stride=1)
      self.bn2 = nn.BatchNorm2d(out_chan)

      self.conv3 = nn.Conv2d(in_chan, int(in_chan / 2), padding=0, kernel_size=1, stride=1)
      self.bn3 = nn.BatchNorm2d(int(in_chan / 2))
      self.conv4 = nn.Conv2d(int(in_chan / 2), out_chan, padding=2, kernel_size=5, stride=1)
      self.bn4 = nn.BatchNorm2d(out_chan)


      self.conv5 = nn.Conv2d(in_chan, out_chan, padding=0, kernel_size=1, stride=1)
      self.bn5 = nn.BatchNorm2d(out_chan)

      self.max_pool = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
      self.conv6 = nn.Conv2d(in_chan, out_chan, padding=0, kernel_size=1, stride=1)
      self.bn6 = nn.BatchNorm2d(out_chan)

    def forward(self, x):
      x1 = F.relu(self.bn1(self.conv1(x)))
      x1 = F.relu(self.bn2(self.conv2(x1)))
      
      
      x2 = F.relu(self.bn3(self.conv3(x)))
      x2 = F.relu(self.bn4(self.conv4(x2)))

      x3 = F.relu(self.bn5(self.conv5(x)))

      x4 = F.relu(self.bn6(self.conv6(self.max_pool(x))))

      return x1 + x2 + x3 + x4
    

class TinyImagenetNet(nn.Module):
    def __init__(self):
        super(TinyImagenetNet, self).__init__()
        # TODO define the layers
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        self.inception1 = InceptionModule(3, 16)
        self.inception2 = InceptionModule(16, 32)
        self.inception3 = InceptionModule(32, 64)
        self.inception4 = InceptionModule(64, 128)
#         self.inception5 = InceptionModule(128, 256)
        
        self.lin = nn.Linear(4*4*128, 200)
        
        # 43% accu
#         self.conv1 = nn.Conv2d(3, 64, padding=1, kernel_size=3, stride=1)
#         self.bn1 = nn.BatchNorm2d(64)
#         self.conv2 = nn.Conv2d(64, 128, padding=1, kernel_size=3, stride=1)
#         self.bn2 = nn.BatchNorm2d(128)
#         self.conv3 = nn.Conv2d(128, 256, padding=1, kernel_size=3, stride=1)
#         self.conv4 = nn.Conv2d(256, 256, padding=1, kernel_size=3, stride=1)
#         self.bn3 = nn.BatchNorm2d(256)
#         self.conv5 = nn.Conv2d(256, 512, padding=1, kernel_size=3, stride=1)
#         self.conv6 = nn.Conv2d(512, 512, padding=1, kernel_size=3, stride=1)
#         self.bn4 = nn.BatchNorm2d(512)
#         self.lin = nn.Linear(4*4*512, 200)
        
        # residual network

        

        # VGG
#         self.conv1 = nn.Conv2d(3, 64, padding=1, kernel_size=3, stride=1)
#         self.bn1 = nn.BatchNorm2d(64)
#         self.conv2 = nn.Conv2d(64, 64, padding=1, kernel_size=3, stride=1)
#         self.bn2 = nn.BatchNorm2d(64)
#         self.conv3 = nn.Conv2d(64, 128, padding=1, kernel_size=3, stride=1)
#         self.bn3 = nn.BatchNorm2d(128)
#         self.conv4 = nn.Conv2d(128, 128, padding=1, kernel_size=3, stride=1)
#         self.bn4 = nn.BatchNorm2d(128)
#         self.conv5 = nn.Conv2d(128, 256, padding=1, kernel_size=3, stride=1)
#         self.bn5 = nn.BatchNorm2d(256)
#         self.conv6 = nn.Conv2d(256, 256, padding=1, kernel_size=3, stride=1)
#         self.bn6 = nn.BatchNorm2d(256)
#         self.conv7 = nn.Conv2d(256, 256, padding=1, kernel_size=3, stride=1)
#         self.bn7 = nn.BatchNorm2d(256)
#         self.conv8 = nn.Conv2d(256, 512, padding=1, kernel_size=3, stride=1)
#         self.bn8 = nn.BatchNorm2d(512)
#         self.conv9 = nn.Conv2d(512, 512, padding=1, kernel_size=3, stride=1)
#         self.bn9 = nn.BatchNorm2d(512)
#         self.conv10 = nn.Conv2d(512, 512, padding=1, kernel_size=3, stride=1)
#         self.bn10 = nn.BatchNorm2d(512)
#         self.conv11 = nn.Conv2d(512, 512, padding=1, kernel_size=3, stride=1)
#         self.bn11 = nn.BatchNorm2d(512)
#         self.conv12 = nn.Conv2d(512, 512, padding=1, kernel_size=3, stride=1)
#         self.bn12 = nn.BatchNorm2d(512)
#         self.conv13 = nn.Conv2d(512, 512, padding=1, kernel_size=3, stride=1)
#         self.bn13 = nn.BatchNorm2d(512)
#         self.lin = nn.Linear(2*2*512, 200)
        self.max_accuracy = 0

    def forward(self, x):
      x = self.max_pool(self.inception1(x))
      x = self.max_pool(self.inception2(x))
      x = self.max_pool(self.inception3(x))
      x = self.max_pool(self.inception4(x))
      x = x.view(-1, 4*4*128)
      x = self.lin(x)
      return F.log_softmax(x)
#       x = self.max_pool(self.inception5(x))
#         x = F.relu(self.bn1(self.conv1(x)))
#         x = F.relu(self.max_pool(self.bn2(self.conv2(x))))
#         x = F.relu(self.bn3(self.conv3(x)))
#         x = F.relu(self.max_pool(self.bn4(self.conv4(x))))
#         x = F.relu(self.bn5(self.conv5(x)))
#         x = F.relu(self.bn6(self.conv6(x)))
#         x = F.relu(self.max_pool(self.bn7(self.conv7(x))))
#         x = F.relu(self.bn8(self.conv8(x)))
#         x = F.relu(self.bn9(self.conv9(x)))
#         x = F.relu(self.max_pool(self.bn10(self.conv10(x))))
#         x = F.relu(self.bn11(self.conv11(x)))
#         x = F.relu(self.bn12(self.conv12(x)))
#         x = F.relu(self.max_pool(self.bn13(self.conv13(x))))
#         x = x.view(-1, 2*2*512)
#         x = self.lin(x)
      

    def loss(self, prediction, label, reduction='elementwise_mean'):
        loss_val = F.cross_entropy(prediction, label.squeeze(), reduction=reduction)
        return loss_val

    def save_model(self, file_path, num_to_keep=1):
        pt_util.save(self, file_path, num_to_keep)
        
    def save_best_model(self, accuracy, file_path, num_to_keep=1):
        # TODO save the model if it is the best
        if accuracy > self.max_accuracy:
          self.save_model(file_path, num_to_keep=num_to_keep)
          self.max_accuracy = accuracy
        
    def load_model(self, file_path):
        pt_util.restore(self, file_path)

    def load_last_model(self, dir_path):
        return pt_util.restore_latest(self, dir_path)

# %% [markdown]
# This time we are giving you the train and test functions, but feel free to modify them if you want.
#
# You may need to return some additional information for the logging portion of this assignment.

# %%
import time
def train(model, device, train_loader, optimizer, epoch, log_interval, stats=True):
    model.train()
    
    total_loss = 0
    num_batches = 0
    for batch_idx, (data, label) in enumerate(train_loader):
        data, label = data.to(device), label.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = model.loss(output, label)
        total_loss += loss.item()
        loss.backward()
        optimizer.step()
        num_batches += 1
        if batch_idx % log_interval == 0:
            print('{} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                time.ctime(time.time()),
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
            
    if stats:
      return total_loss / num_batches

def test(model, device, test_loader, return_images=False, log_interval=None, stats=False):
    model.eval()
    test_loss = 0
    correct = 0

    correct_images = []
    correct_values = []

    error_images = []
    predicted_values = []
    gt_values = []
    with torch.no_grad():
        for batch_idx, (data, label) in enumerate(test_loader):
            data, label = data.to(device), label.to(device)
            output = model(data)
            test_loss_on = model.loss(output, label, reduction='sum').item()
            test_loss += test_loss_on
            pred = output.max(1)[1]
            correct_mask = pred.eq(label.view_as(pred))
            num_correct = correct_mask.sum().item()
            correct += num_correct
            if return_images:
                if num_correct > 0:
                    correct_images.append(data[correct_mask, ...].data.cpu().numpy())
                    correct_value_data = label[correct_mask].data.cpu().numpy()[:, 0]
                    correct_values.append(correct_value_data)
                if num_correct < len(label):
                    error_data = data[~correct_mask, ...].data.cpu().numpy()
                    error_images.append(error_data)
                    predicted_value_data = pred[~correct_mask].data.cpu().numpy()
                    predicted_values.append(predicted_value_data)
                    gt_value_data = label[~correct_mask].data.cpu().numpy()[:, 0]
                    gt_values.append(gt_value_data)
            if log_interval is not None and batch_idx % log_interval == 0:
                print('{} Test: [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    time.ctime(time.time()),
                    batch_idx * len(data), len(test_loader.dataset),
                    100. * batch_idx / len(test_loader), test_loss_on))
    if return_images:
        correct_images = np.concatenate(correct_images, axis=0)
        error_images = np.concatenate(error_images, axis=0)
        predicted_values = np.concatenate(predicted_values, axis=0)
        correct_values = np.concatenate(correct_values, axis=0)
        gt_values = np.concatenate(gt_values, axis=0)

    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset), test_accuracy))
    
    
    if stats:
      return test_loss, test_accuracy
    
    if return_images:
      return correct_images, correct_values, error_images, predicted_values, gt_values

# %% [markdown]
# # PART 3: Loading Data
# PyTorch has a nice interface for dealing with a variety of data. You can read a good tutorial here https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
# Your friendly neighborhood TAs have made it even easier by preprocessing the data into a nice format. The data you uploaded is stored using hdf5 files which can be acecces a lot like Numpy arrays using the h5py package. In each of the files, there is a "dataset" called 'images', and one called 'labels'. Read more about h5py here http://docs.h5py.org/en/latest/quick.html
#
# Speed hint: With small datasets, it is almost always a good idea to cache the data to disk rather than continually read from files.

# %%
# Data loader
class H5Dataset(torch.utils.data.Dataset):
    def __init__(self, h5_file, transform=None):
        # TODO Implement data loading.
        f = h5py.File(h5_file, 'r')
        self.images = f['images'].value        
        self.labels = torch.LongTensor(f['labels'].value)
        self.transform = transform
        
    def __len__(self):
        # TODO Implement the length function
        return self.images.shape[0]

    def __getitem__(self, idx):
        # TODO implement the getitem function
        # You should return a tuple of:
        #    a torch tensor containing single image in CxHxW format and
        #    the label as a single tensor scalar.
        data = self.images[idx]
        label = self.labels[idx]
        
        if self.transform:
            data = self.transform(data)
        return (data, label)

# %% [markdown]
# # Part 4: Dataset Augmentation
# In the MNIST assignment, we didn't do any data augmentation because MNIST is kind of easy.
#
# In this assignment, you may find that data augmentation helps you a lot (or possibly hurts your performance).
#
# You can find a bunch preimplemented here https://pytorch.org/docs/stable/torchvision/transforms.html and you can also do your own as seen in the tutorial from part 3.
#
# Play around with various data augmentations we will suggest some.
#
# - ToPILImage - This one is useful for a lot of the built in transforms which expect PIL images.
# - RandomHorizontalFlip
# - RandomResizedCrop
# - ColorJitter
# - RandomRotation
# - Normalize
# - Adding various types of noise
# - ToTensor - PyTorch expects the output from the dataset to be a tensor in CxHxW format.
#
#
# Note: You should be careful about which of these you apply to the test data. You usually don't want to apply noise to the test data, but you do want to normalize it in the same way for example.

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
train_transforms = transforms.Compose([transforms.ToPILImage(), transforms.RandomHorizontalFlip(), transforms.ToTensor(), normalize])

test_transforms = transforms.Compose([transforms.ToPILImage(), transforms.ToTensor(), normalize])

data_train = H5Dataset(DATA_PATH + 'train.h5', transform=train_transforms)
data_test = H5Dataset(DATA_PATH + 'val.h5', transform=test_transforms)

# %%
model = TinyImagenetNet()
model
# Out:
# TinyImagenetNet(
#   (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (inception1): InceptionModule(
#     (conv1): Conv2d(3, 1, kernel_size=(1, 1), stride=(1, 1))
#     (bn1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#     (bn3): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (bn4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (max_pool): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#     (bn6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (inception2): InceptionModule(
#     (conv1): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1))
#     (bn1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(8, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#     (bn3): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(8, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (bn4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (max_pool): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#     (bn6): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (inception3): InceptionModule(
#     (conv1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#     (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#     (bn3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(16, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (bn4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (max_pool): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#     (bn6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (inception4): InceptionModule(
#     (conv1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#     (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#     (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (bn4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (max_pool): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#     (bn6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc1): Linear(in_features=2048, out_features=200, bias=True)
# )

# %% [markdown]
# # Part 5: Training the network
# Generally, it is useful to see how your training is going. Often people print their loss to make sure it goes down and their accuracy to make sure it goes up. But pictures are better than words. So for this part, you should record and plot the training loss, test loss, and test accuracy (and whatever else you want).
#
# We have created a very simple logging interface which essentially just saves and restores files via pickle in pt_util. Saving and restoring log data is important if you end your run early and want to continue where you left off rather than starting over.
#
# We have also provided a plot function which can plot a single line graph. You can use it and plot each value independently, or change it to plot them all in one graph.
#
#
# __Important note: Do not forget to title your graphs and label your axes. Plots are meaningless without a way to read them.__
#
# Second Note: It will be helpful for you when deciding what network structure, data augmentation, and such work to title the graphs accordingly so you remember.
# Third Note: The default setup right now saves and restores the network weights from a single folder. When you modify network architectures, you may want to save the resulting files in different folders (with appropriate names).
#
# We also provided a function for showing some results, because it's not satisfying to train a neural net, you also want to see what it can do! This can also be useful for figuring out what your network is doing well, and what it is failing at. This type of error analysis is very common when training neural networks.

# %%
# Play around with these constants, you may find a better setting.
BATCH_SIZE = 256
TEST_BATCH_SIZE = 10
EPOCHS = 50
LEARNING_RATE = 0.01
MOMENTUM = 0.9
USE_CUDA = True
PRINT_INTERVAL = 100
WEIGHT_DECAY = 0.0001

MODEL_PATH = DATA_PATH + 'inception_4/'
LOG_PATH = MODEL_PATH + 'log.pkl'

# Now the actual training code
use_cuda = USE_CUDA and torch.cuda.is_available()

device = torch.device("cuda" if use_cuda else "cpu")
print('Using device', device)
import multiprocessing
print('num cpus:', multiprocessing.cpu_count())

kwargs = {'num_workers': multiprocessing.cpu_count(),
          'pin_memory': True} if use_cuda else {}

class_names = [line.strip().split(', ') for line in open(DATA_PATH + 'class_names.txt')]
name_to_class = {line[1]: line[0] for line in class_names}
class_names = [line[1] for line in class_names]


train_loader = torch.utils.data.DataLoader(data_train, batch_size=BATCH_SIZE,
                                           shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(data_test, batch_size=TEST_BATCH_SIZE,
                                          shuffle=False, **kwargs)

model = TinyImagenetNet().to(device)
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
start_epoch = model.load_last_model(MODEL_PATH + 'checkpoints')

# You may want to define another default for your log data depending on how you save it.
log_data = pt_util.read_log(LOG_PATH)
print("reading log data:", log_data)

correct_images, correct_val, error_images, predicted_val, gt_val = test(model, device, test_loader, True)

correct_images = pt_util.to_scaled_uint8(correct_images.transpose(0, 2, 3, 1))
error_images = pt_util.to_scaled_uint8(error_images.transpose(0, 2, 3, 1))
pt_util.show_images(correct_images, ['correct: %s' % class_names[aa] for aa in correct_val])
pt_util.show_images(error_images, ['pred: %s, actual: %s' % (class_names[aa], class_names[bb]) for aa, bb in zip(predicted_val, gt_val)])

try:
    if not log_data:
      test_losses = []
      test_accuracies = []
      train_losses = []
      print("Creating new log data for this run")
      log_data = {"train_loss": train_losses, "test_loss": test_losses, "test_accuracy": test_accuracies}

    for epoch in range(start_epoch, EPOCHS + 1):
        print("Epoch: {}".format(epoch))
        train_loss = train(model, device, train_loader, optimizer, epoch, PRINT_INTERVAL, stats=True)
        test_loss, test_accuracy = test(model, device, test_loader, stats=True)
        
        print("save checkpoint")
        model.save_model(MODEL_PATH + 'checkpoints/%03d.pt' % epoch, 0)
        
        print("saving model?")
        model.save_best_model(test_accuracy, MODEL_PATH + 'acc-{}-epoch-{}.model'.format(test_accuracy, epoch), num_to_keep=5)

        
        log_data['train_loss'] += [train_loss]
        log_data['test_loss'] += [test_loss]
        log_data['test_accuracy'] += [test_accuracy]
        
        print("saving log data: ", log_data)
        pt_util.write_log(LOG_PATH, log_data)
    
    
except KeyboardInterrupt as ke:
    print('Interrupted')
except:
    import traceback
    traceback.print_exc()
finally:
    # Always save the most recent model, but don't delete any existing ones.
#     model.save_model(MODEL_PATH + 'checkpoints/%03d.pt' % epoch, 0)
    
    # Show some current correct/incorrect images.
    correct_images = pt_util.to_scaled_uint8(correct_images.transpose(0, 2, 3, 1))
    error_images = pt_util.to_scaled_uint8(error_images.transpose(0, 2, 3, 1))
    pt_util.show_images(correct_images, ['correct: %s' % class_names[aa] for aa in correct_val])
    pt_util.show_images(error_images, ['pred: %s, actual: %s' % (class_names[aa], class_names[bb]) for aa, bb in zip(predicted_val, gt_val)])
# Out:
# Using device cuda
# num cpus: 2
# reading log data: None
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:106: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Test set: Average loss: 5.3008, Accuracy: 50/10000 (0%)
# Creating new log data for this run
# Epoch: 0
# Wed Oct 31 00:24:28 2018 Train Epoch: 0 [0/100000 (0%)]	Loss: 5.653493
# Wed Oct 31 00:24:53 2018 Train Epoch: 0 [25600/100000 (26%)]	Loss: 4.744731
# Wed Oct 31 00:25:17 2018 Train Epoch: 0 [51200/100000 (51%)]	Loss: 4.343525
# Wed Oct 31 00:25:42 2018 Train Epoch: 0 [76800/100000 (77%)]	Loss: 3.951623
#
# Test set: Average loss: 4.2773, Accuracy: 1240/10000 (12%)
#
# save checkpoint
# Saved /gdrive/My Drive/colab_files/homework1/tiny_imagenet/inception_4/checkpoints/000.pt
#
# saving model?
# Saved /gdrive/My Drive/colab_files/homework1/tiny_imagenet/inception_4/acc-12.4-epoch-0.model
#
# saving log data:  {'train_loss': [4.486057274786712], 'test_loss': [4.277260341262817], 'test_accuracy': [12.4]}
# Epoch: 1
# Wed Oct 31 00:26:20 2018 Train Epoch: 1 [0/100000 (0%)]	Loss: 3.955858
# Wed Oct 31 00:26:45 2018 Train Epoch: 1 [25600/100000 (26%)]	Loss: 3.751202
# Wed Oct 31 00:27:09 2018 Train Epoch: 1 [51200/100000 (51%)]	Loss: 3.625335
# Wed Oct 31 00:27:34 2018 Train Epoch: 1 [76800/100000 (77%)]	Loss: 3.485437
#
# Test set: Average loss: 3.5222, Accuracy: 2245/10000 (22%)
#
# save checkpoint
# Saved /gdrive/My Drive/colab_files/homework1/tiny_imagenet/inception_4/checkpoints/001.pt
#
# saving model?
# Saved /gdrive/My Drive/colab_files/homework1/tiny_imagenet/inception_4/acc-22.45-epoch-1.model
#
# saving log data:  {'train_loss': [4.486057274786712, 3.603036759149693], 'test_loss': [4.277260341262817, 3.52218094291687], 'test_accuracy': [12.4, 22.45]}
# Epoch: 2
# Wed Oct 31 00:28:12 2018 Train Epoch: 2 [0/100000 (0%)]	Loss: 3.359642
# Wed Oct 31 00:28:36 2018 Train Epoch: 2 [25600/100000 (26%)]	Loss: 3.319434
# Wed Oct 31 00:29:01 2018 Train Epoch: 2 [51200/100000 (51%)]	Loss: 3.407555
# Wed Oct 31 00:29:26 2018 Train Epoch: 2 [76800/100000 (77%)]	Loss: 3.303741
#
# Test set: Average loss: 3.6465, Accuracy: 2088/10000 (21%)
#
# save checkpoint
# Saved /gdrive/My Drive/colab_files/homework1/tiny_imagenet/inception_4/checkpoints/002.pt
#
# saving model?
# saving log data:  {'train_loss': [4.486057274786712, 3.603036759149693, 3.2508441511627355], 'test_loss': [4.277260341262817, 3.52218094291687, 3.646483169364929], 'test_accuracy': [12.4, 22.45, 20.88]}
# Epoch: 3
# Wed Oct 31 00:30:04 2018 Train Epoch: 3 [0/100000 (0%)]	Loss: 3.098757
# Wed Oct 31 00:30:28 2018 Train Epoch: 3 [25600/100000 (26%)]	Loss: 3.120464
# Wed Oct 31 00:30:53 2018 Train Epoch: 3 [51200/100000 (51%)]	Loss: 3.094810
# Wed Oct 31 00:31:17 2018 Train Epoch: 3 [76800/100000 (77%)]	Loss: 3.174014
#
# Test set: Average loss: 3.4201, Accuracy: 2419/10000 (24%)
#
# save checkpoint
# Saved /gdrive/My Drive/colab_files/homework1/tiny_imagenet/inception_4/checkpoints/003.pt
#
# saving model?
# Saved /gdrive/My Drive/colab_files/homework1/tiny_imagenet/inception_4/acc-24.19-epoch-3.model
#
# saving log data:  {'train_loss': [4.486057274786712, 3.603036759149693, 3.2508441511627355, 3.029498540531949], 'test_loss': [4.277260341262817, 3.52218094291687, 3.646483169364929, 3.420116480255127], 'test_accuracy': [12.4, 22.45, 20.88, 24.19]}
# Epoch: 4
# Wed Oct 31 00:31:55 2018 Train Epoch: 4 [0/100000 (0%)]	Loss: 2.937972
# Wed Oct 31 00:32:20 2018 Train Epoch: 4 [25600/100000 (26%)]	Loss: 2.829972
# Wed Oct 31 00:32:45 2018 Train Epoch: 4 [51200/100000 (51%)]	Loss: 2.709058
# Wed Oct 31 00:33:09 2018 Train Epoch: 4 [76800/100000 (77%)]	Loss: 2.814660
#
# Test set: Average loss: 3.1501, Accuracy: 2920/10000 (29%)
#
# save checkpoint
# Saved /gdrive/My Drive/colab_files/homework1/tiny_imagenet/inception_4/checkpoints/004.pt
#
# saving model?
# Saved /gdrive/My Drive/colab_files/homework1/tiny_imagenet/inception_4/acc-29.2-epoch-4.model
#
# saving log data:  {'train_loss': [4.486057274786712, 3.603036759149693, 3.2508441511627355, 3.029498540531949, 2.8624981693599536], 'test_loss': [4.277260341262817, 3.52218094291687, 3.646483169364929, 3.420116480255127, 3.1501468883514403], 'test_accuracy': [12.4, 22.45, 20.88, 24.19, 29.2]}
# Epoch: 5
# Wed Oct 31 00:33:47 2018 Train Epoch: 5 [0/100000 (0%)]	Loss: 2.594288
# Wed Oct 31 00:34:12 2018 Train Epoch: 5 [25600/100000 (26%)]	Loss: 2.658382
# Wed Oct 31 00:34:36 2018 Train Epoch: 5 [51200/100000 (51%)]	Loss: 2.667042
# Wed Oct 31 00:35:01 2018 Train Epoch: 5 [76800/100000 (77%)]	Loss: 2.771972
#
# Test set: Average loss: 3.0082, Accuracy: 3142/10000 (31%)
#
# save checkpoint
# Saved /gdrive/My Drive/colab_files/homework1/tiny_imagenet/inception_4/checkpoints/005.pt
#
# saving model?
# Saved /gdrive/My Drive/colab_files/homework1/tiny_imagenet/inception_4/acc-31.42-epoch-5.model
#
# saving log data:  {'train_loss': [4.486057274786712, 3.603036759149693, 3.2508441511627355, 3.029498540531949, 2.8624981693599536, 2.730797581660473], 'test_loss': [4.277260341262817, 3.52218094291687, 3.646483169364929, 3.420116480255127, 3.1501468883514403, 3.008204883480072], 'test_accuracy': [12.4, 22.45, 20.88, 24.19, 29.2, 31.
443909620285033, 2.950030626678467, 2.9260965738296507, 2.9609690269470215, 2.9715509269714357, 3.015413589859009, 2.9862525301933287, 3.0449292497634888, 3.0340435319423675, 3.0443018174171446, 3.1200144609451295, 3.2739319252967833, 3.1724568345546724, 3.196663911628723, 3.2201830517292023, 3.2622673605918884, 3.283263510990143, 3.3314168045043946, 3.3223486413002012, 3.380571430873871, 3.3465506459236143, 3.4843829696655275, 3.423337257194519, 3.5896068940639494, 3.485295973491669, 3.5080525380134584], 'test_accuracy': [12.4, 22.45, 20.88, 24.19, 29.2, 31.42, 31.45, 31.74, 32.89, 35.88, 34.81, 32.56, 30.56, 35.17, 32.71, 36.54, 36.8, 34.97, 36.59, 34.76, 37.91, 37.57, 37.35, 36.94, 36.06, 37.64, 36.81, 37.4, 36.92, 37.05, 36.04, 37.07, 36.55, 37.41, 36.94, 36.21, 34.53, 36.11, 36.12, 35.61, 35.78, 35.77, 35.0, 35.74, 35.74, 35.71, 34.72, 36.2, 33.35, 35.44, 34.77]}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-ffa570e969d6> in <module>()
#      87     correct_images = pt_util.to_scaled_uint8(correct_images.transpose(0, 2, 3, 1))
#      88     error_images = pt_util.to_scaled_uint8(error_images.transpose(0, 2, 3, 1))
# ---> 89     pt_util.show_images(correct_images, ['correct: %s' % class_names[aa] for aa in correct_val])
#      90     pt_util.show_images(error_images, ['pred: %s, actual: %s' % (class_names[aa], class_names[bb]) for aa, bb in zip(predicted_val, gt_val)])
#
# /gdrive/My Drive/colab_files/homework1/pt_util.py in show_images(images, titles, columns, max_rows)
#     158         if titles is not None and ii < len(titles):
#     159             plt.title(str(titles[ii]))
# --> 160         plt.imshow(image)
#     161     plt.show()
#     162
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3099                         filternorm=filternorm, filterrad=filterrad,
#    3100                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3101                         **kwargs)
#    3102     finally:
#    3103         ax._hold = washold
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5129                               resample=resample, **kwargs)
#    5130
# -> 5131         im.set_data(X)
#    5132         im.set_alpha(alpha)
#    5133         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in set_data(self, A)
#     620         if not (self._A.ndim == 2
#     621                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 622             raise TypeError("Invalid dimensions for image data")
#     623
#     624         self._imcache = None
#
# TypeError: Invalid dimensions for image data

# %%
import matplotlib.pyplot as plt
def plot_loss(x_values, train_loss, test_loss, title, xlabel, ylabel):
    plt.figure(figsize=(20, 10))
    plt.plot(x_values, train_loss, label='train loss')
    plt.plot(x_values, test_loss, label='test loss')
    plt.title(title)
    plt.legend()
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
MODEL_PATH = DATA_PATH + 'vgg_16_bn/'
LOG_PATH = MODEL_PATH + 'log.pkl'

log_data = pt_util.read_log(LOG_PATH)
epochs = np.arange(len(log_data['train_loss']))
plot_loss(epochs, log_data['train_loss'], log_data['test_loss'], 'Epoch vs Loss', 'Epochs', 'Loss')
pt_util.plot(epochs, log_data['test_accuracy'], 'Epoch vs Test Accuracy', 'Epochs', 'Accuracy')

# %%
MODEL_PATH = DATA_PATH + 'inception_4/'
LOG_PATH = MODEL_PATH + 'log.pkl'

log_data = pt_util.read_log(LOG_PATH)
epochs = np.arange(len(log_data['train_loss']))
plot_loss(epochs, log_data['train_loss'], log_data['test_loss'], 'Epoch vs Loss', 'Epochs', 'Loss')
pt_util.plot(epochs, log_data['test_accuracy'], 'Epoch vs Test Accuracy', 'Epochs', 'Accuracy')

# %% [markdown]
# # Part 6: ImageNet!
# ImageNet is the big granddaddy of supervised vision datasets. It's the dataset that got the whole deep learning train running. We thought it would be fun for you guys to try your hand at it.
#
# A few notes:
# - Downloading ImageNet should take about 7 minutues. Extracting should take another 7 minutes. So run this code, then go have a coffee or whatever.
# - The data will be removed after 24 hours or so. That's just how Colab works. Each time you reset the environment, you will also have to redownload ImageNet.
#     - I would recommend against storing it on your on Google Drive though as that is way slower to read during training.
#     - Through extensive testing, we have found that the fastest way to get the data is the code we provide (faster than saving to google drive, uploading by hand, etc.)
# - Reading images directly with PIL seems to have issues on Colab. Instead try cv2.imread.
#     - cv2.imread returns images in bgr order. To go from bgr -> rgb, use    `im = im[:, :, ::-1]`
# - The images are provided such that the minimum side length is at least 128 unless the original image was too small for it to be shrunk.
#     - transforms.Resize will be your friend
# - It seams you cannot use a batch size > 64 x 128 x 128 x 3 while still using multiprocessing due to Colab limitations. You can use larger batches if you set num_workers = 0, but it will be much slower.
# - This dataset has 1000 classes, whereas Tiny ImageNet only had 200.
# - You will probably want to save your results more than once every epoch since Colab may spurriously shut down your session.
# - We know this takes a long time to run. Try leaving it overnight. We don't expect you to get state-of-the-art performance.
# - `glob.glob` is a good Python function for reading lots of folder/file names, but it does not return a sorted list.

# %%
# Downloads and extracts the data
if not os.path.exists('imagenet128'):
    # !echo $(date +%x_%r)
    # !gsutil cp gs://imagenet-cropped/imagenet128.tar .
    # !echo $(date +%x_%r)
    # !tar -xf imagenet128.tar
    # !echo $(date +%x_%r)
    # !ls imagenet128/train | head -4
# Out:
# 10/30/2018_08:20:08 PM
# Copying gs://imagenet-cropped/imagenet128.tar...
# \ [1 files][ 23.7 GiB/ 23.7 GiB]   44.5 MiB/s
# Operation completed over 1 objects/23.7 GiB.
# 10/30/2018_08:26:26 PM
# 10/30/2018_08:32:03 PM
# n01440764
# n01443537
# n01484850
# n01491361

# %%
# Sets up synset data. Have a look at what is in these dictionaries as they may help you with debugging.
import json
import glob
import os
import cv2


imagenet_synset_data = json.load(open('imagenet128/imagenet_synsets.json'))
synset_id_to_cls = {val['id']: int(key) for key, val in imagenet_synset_data.items()}

# %%
# Data loader
class ImageFolderLoader(torch.utils.data.Dataset):
    def __init__(self, folder, transform=None):
      
      self.transform = transform      
      self.data_paths = []
      for img_path in glob.glob(folder + "/*/*.JPEG"):
        self.data_paths += [img_path]

    def __len__(self):
      return len(self.data_paths)

    def __getitem__(self, idx):
      img_path = self.data_paths[idx]      
      img = cv2.imread(img_path)
      img = img[:, :, ::-1]
      
      if self.transform:
            img = self.transform(img)
        
      
      return (img, synset_id_to_cls[img_path.split('/')[2]])

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
train_transforms = transforms.Compose([transforms.ToPILImage(), transforms.Resize(size=(128, 128)), transforms.ToTensor(), normalize])
test_transforms = transforms.Compose([transforms.ToPILImage(), transforms.Resize(size=(128, 128)), transforms.ToTensor(), normalize])

data_train = ImageFolderLoader('imagenet128/train', transform=train_transforms)
assert(len(data_train) == 1281167)
data_test = ImageFolderLoader('imagenet128/val', transform=test_transforms)
assert(len(data_test) == 50000)

# %%
class FullImagenetNet(TinyImagenetNet):
    def __init__(self):
        super(FullImagenetNet, self).__init__()
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
        self.conv1 = nn.Conv2d(3, 16, padding=1, kernel_size=3, stride=1)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(16, 32, padding=1, kernel_size=3, stride=1)
        self.bn2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 64, padding=1, kernel_size=3, stride=1)
        self.bn3 = nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(64, 128, padding=1, kernel_size=3, stride=1)
        self.bn4 = nn.BatchNorm2d(128)
        self.conv5 = nn.Conv2d(128, 256, padding=1, kernel_size=3, stride=1)
        self.bn5 = nn.BatchNorm2d(256)
        self.conv6 = nn.Conv2d(256, 512, padding=1, kernel_size=3, stride=1)
        self.bn6 = nn.BatchNorm2d(512)
        self.lin = nn.Linear(2*2*512, 1000)
        
        self.max_accuracy = 0

    def forward(self, x):
        # TODO define the forward pass
        x = F.relu(self.max_pool(self.bn1(self.conv1(x))))
        x = F.relu(self.max_pool(self.bn2(self.conv2(x))))
        x = F.relu(self.max_pool(self.bn3(self.conv3(x))))
        x = F.relu(self.max_pool(self.bn4(self.conv4(x))))
        x = F.relu(self.max_pool(self.bn5(self.conv5(x))))
        x = F.relu(self.max_pool(self.bn6(self.conv6(x))))

        x = x.view(-1, 2*2*512)
        x = self.lin(x)
        
        return F.log_softmax(x)

# %%
BATCH_SIZE = 64
TEST_BATCH_SIZE = 50
EPOCHS = 200
LEARNING_RATE = 0.01
MOMENTUM = 0.9
USE_CUDA = True
PRINT_INTERVAL = 1000
WEIGHT_DECAY = 0.0005
CHECKPOINT_PATH = BASE_PATH + 'imagenet_full/checkpoints'
LOG_PATH = BASE_PATH + 'imagenet_full/' + 'log.pkl'
MODEL_PATH = BASE_PATH + 'imagenet_full/'

use_cuda = USE_CUDA and torch.cuda.is_available()

device = torch.device("cuda" if use_cuda else "cpu")
print('Using device', device)
import multiprocessing
print('num cpus:', multiprocessing.cpu_count())

kwargs = {'num_workers': multiprocessing.cpu_count(),
          'pin_memory': True} if use_cuda else {}

log_data = pt_util.read_log(LOG_PATH, None)
print(log_data)

class_names = sorted([(int(key), val['label'].split(',')[0]) for key, val in imagenet_synset_data.items()])
name_to_class = {line[1]: line[0] for line in class_names}
class_names = [line[1] for line in class_names]

train_loader = torch.utils.data.DataLoader(data_train, batch_size=BATCH_SIZE,
                                           shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(data_test, batch_size=TEST_BATCH_SIZE,
                                          shuffle=False, **kwargs)

model = FullImagenetNet().to(device)
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
start_epoch = model.load_last_model(MODEL_PATH) + 1
print("Start Epoch: ", start_epoch)

try:
    if not log_data:
      test_losses = []
      test_accuracies = []
      train_losses = []
      print("Creating new log data for this run")
      log_data = {"train_loss": train_losses, "test_loss": test_losses, "test_accuracy": test_accuracies}
    
    for epoch in range(start_epoch, EPOCHS + 1):
        train_loss = train(model, device, train_loader, optimizer, epoch, PRINT_INTERVAL, stats=True)
        test_loss, test_accuracy = test(model, device, test_loader, False, stats=True)

        print("save checkpoint")
        model.save_model(MODEL_PATH + '%03d.pt' % epoch, 0)

        print("saving model?")
        model.save_best_model(test_accuracy, MODEL_PATH + 'acc-{}-epoch-{}.model'.format(test_accuracy, epoch), num_to_keep=5)


        log_data['train_loss'] += [train_loss]
        log_data['test_loss'] += [test_loss]
        log_data['test_accuracy'] += [test_accuracy]

        print("saving log data: ", log_data)
        pt_util.write_log(LOG_PATH, log_data)

except KeyboardInterrupt as ke:
    print('Interrupted')
except:
    import traceback
    traceback.print_exc()
finally:
    model.save_model(CHECKPOINT_PATH + '/%03d.pt' % epoch, 0)
# Out:
# Using device cuda
# num cpus: 2
# {'train_loss': [4.39100306772127, 3.376638364825217, 3.1451884585128593, 3.040582446191175, 2.978509414135871, 2.9373717507530483], 'test_loss': [3.883790785179138, 3.596280732460022, 3.547088831329346, 3.478510228919983, 3.335424249305725, 3.465609636955261], 'test_accuracy': [23.268, 27.162, 27.986, 29.026, 31.242, 29.354]}
# Restoring:
# inception1.conv1.weight -> 	torch.Size([1, 3, 1, 1]) = 0MB
# inception1.conv1.bias -> 	torch.Size([1]) = 0MB
# inception1.bn1.weight -> 	torch.Size([1]) = 0MB
# inception1.bn1.bias -> 	torch.Size([1]) = 0MB
# inception1.bn1.running_mean -> 	torch.Size([1]) = 0MB
# inception1.bn1.running_var -> 	torch.Size([1]) = 0MB
# inception1.bn1.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception1.conv2.weight -> 	torch.Size([16, 1, 3, 3]) = 0MB
# inception1.conv2.bias -> 	torch.Size([16]) = 0MB
# inception1.bn2.weight -> 	torch.Size([16]) = 0MB
# inception1.bn2.bias -> 	torch.Size([16]) = 0MB
# inception1.bn2.running_mean -> 	torch.Size([16]) = 0MB
# inception1.bn2.running_var -> 	torch.Size([16]) = 0MB
# inception1.bn2.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception1.conv3.weight -> 	torch.Size([16, 3, 1, 1]) = 0MB
# inception1.conv3.bias -> 	torch.Size([16]) = 0MB
# inception1.bn3.weight -> 	torch.Size([1]) = 0MB
# inception1.bn3.bias -> 	torch.Size([1]) = 0MB
# inception1.bn3.running_mean -> 	torch.Size([1]) = 0MB
# inception1.bn3.running_var -> 	torch.Size([1]) = 0MB
# inception1.bn3.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception1.conv4.weight -> 	torch.Size([16, 1, 5, 5]) = 0MB
# inception1.conv4.bias -> 	torch.Size([16]) = 0MB
# inception1.bn4.weight -> 	torch.Size([16]) = 0MB
# inception1.bn4.bias -> 	torch.Size([16]) = 0MB
# inception1.bn4.running_mean -> 	torch.Size([16]) = 0MB
# inception1.bn4.running_var -> 	torch.Size([16]) = 0MB
# inception1.bn4.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception1.bn5.weight -> 	torch.Size([16]) = 0MB
# inception1.bn5.bias -> 	torch.Size([16]) = 0MB
# inception1.bn5.running_mean -> 	torch.Size([16]) = 0MB
# inception1.bn5.running_var -> 	torch.Size([16]) = 0MB
# inception1.bn5.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception1.bn6.weight -> 	torch.Size([16]) = 0MB
# inception1.bn6.bias -> 	torch.Size([16]) = 0MB
# inception1.bn6.running_mean -> 	torch.Size([16]) = 0MB
# inception1.bn6.running_var -> 	torch.Size([16]) = 0MB
# inception1.bn6.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception2.conv1.weight -> 	torch.Size([8, 16, 1, 1]) = 0MB
# inception2.conv1.bias -> 	torch.Size([8]) = 0MB
# inception2.bn1.weight -> 	torch.Size([8]) = 0MB
# inception2.bn1.bias -> 	torch.Size([8]) = 0MB
# inception2.bn1.running_mean -> 	torch.Size([8]) = 0MB
# inception2.bn1.running_var -> 	torch.Size([8]) = 0MB
# inception2.bn1.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception2.conv2.weight -> 	torch.Size([32, 8, 3, 3]) = 0MB
# inception2.conv2.bias -> 	torch.Size([32]) = 0MB
# inception2.bn2.weight -> 	torch.Size([32]) = 0MB
# inception2.bn2.bias -> 	torch.Size([32]) = 0MB
# inception2.bn2.running_mean -> 	torch.Size([32]) = 0MB
# inception2.bn2.running_var -> 	torch.Size([32]) = 0MB
# inception2.bn2.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception2.conv3.weight -> 	torch.Size([32, 16, 1, 1]) = 0MB
# inception2.conv3.bias -> 	torch.Size([32]) = 0MB
# inception2.bn3.weight -> 	torch.Size([8]) = 0MB
# inception2.bn3.bias -> 	torch.Size([8]) = 0MB
# inception2.bn3.running_mean -> 	torch.Size([8]) = 0MB
# inception2.bn3.running_var -> 	torch.Size([8]) = 0MB
# inception2.bn3.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception2.conv4.weight -> 	torch.Size([32, 8, 5, 5]) = 0MB
# inception2.conv4.bias -> 	torch.Size([32]) = 0MB
# inception2.bn4.weight -> 	torch.Size([32]) = 0MB
# inception2.bn4.bias -> 	torch.Size([32]) = 0MB
# inception2.bn4.running_mean -> 	torch.Size([32]) = 0MB
# inception2.bn4.running_var -> 	torch.Size([32]) = 0MB
# inception2.bn4.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception2.bn5.weight -> 	torch.Size([32]) = 0MB
# inception2.bn5.bias -> 	torch.Size([32]) = 0MB
# inception2.bn5.running_mean -> 	torch.Size([32]) = 0MB
# inception2.bn5.running_var -> 	torch.Size([32]) = 0MB
# inception2.bn5.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception2.bn6.weight -> 	torch.Size([32]) = 0MB
# inception2.bn6.bias -> 	torch.Size([32]) = 0MB
# inception2.bn6.running_mean -> 	torch.Size([32]) = 0MB
# inception2.bn6.running_var -> 	torch.Size([32]) = 0MB
# inception2.bn6.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception3.conv1.weight -> 	torch.Size([16, 32, 1, 1]) = 0MB
# inception3.conv1.bias -> 	torch.Size([16]) = 0MB
# inception3.bn1.weight -> 	torch.Size([16]) = 0MB
# inception3.bn1.bias -> 	torch.Size([16]) = 0MB
# inception3.bn1.running_mean -> 	torch.Size([16]) = 0MB
# inception3.bn1.running_var -> 	torch.Size([16]) = 0MB
# inception3.bn1.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception3.conv2.weight -> 	torch.Size([64, 16, 3, 3]) = 0MB
# inception3.conv2.bias -> 	torch.Size([64]) = 0MB
# inception3.bn2.weight -> 	torch.Size([64]) = 0MB
# inception3.bn2.bias -> 	torch.Size([64]) = 0MB
# inception3.bn2.running_mean -> 	torch.Size([64]) = 0MB
# inception3.bn2.running_var -> 	torch.Size([64]) = 0MB
# inception3.bn2.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception3.conv3.weight -> 	torch.Size([64, 32, 1, 1]) = 0MB
# inception3.conv3.bias -> 	torch.Size([64]) = 0MB
# inception3.bn3.weight -> 	torch.Size([16]) = 0MB
# inception3.bn3.bias -> 	torch.Size([16]) = 0MB
# inception3.bn3.running_mean -> 	torch.Size([16]) = 0MB
# inception3.bn3.running_var -> 	torch.Size([16]) = 0MB
# inception3.bn3.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception3.conv4.weight -> 	torch.Size([64, 16, 5, 5]) = 0MB
# inception3.conv4.bias -> 	torch.Size([64]) = 0MB
# inception3.bn4.weight -> 	torch.Size([64]) = 0MB
# inception3.bn4.bias -> 	torch.Size([64]) = 0MB
# inception3.bn4.running_mean -> 	torch.Size([64]) = 0MB
# inception3.bn4.running_var -> 	torch.Size([64]) = 0MB
# inception3.bn4.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception3.bn5.weight -> 	torch.Size([64]) = 0MB
# inception3.bn5.bias -> 	torch.Size([64]) = 0MB
# inception3.bn5.running_mean -> 	torch.Size([64]) = 0MB
# inception3.bn5.running_var -> 	torch.Size([64]) = 0MB
# inception3.bn5.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception3.bn6.weight -> 	torch.Size([64]) = 0MB
# inception3.bn6.bias -> 	torch.Size([64]) = 0MB
# inception3.bn6.running_mean -> 	torch.Size([64]) = 0MB
# inception3.bn6.running_var -> 	torch.Size([64]) = 0MB
# inception3.bn6.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception4.conv1.weight -> 	torch.Size([32, 64, 1, 1]) = 0MB
# inception4.conv1.bias -> 	torch.Size([32]) = 0MB
# inception4.bn1.weight -> 	torch.Size([32]) = 0MB
# inception4.bn1.bias -> 	torch.Size([32]) = 0MB
# inception4.bn1.running_mean -> 	torch.Size([32]) = 0MB
# inception4.bn1.running_var -> 	torch.Size([32]) = 0MB
# inception4.bn1.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception4.conv2.weight -> 	torch.Size([128, 32, 3, 3]) = 0MB
# inception4.conv2.bias -> 	torch.Size([128]) = 0MB
# inception4.bn2.weight -> 	torch.Size([128]) = 0MB
# inception4.bn2.bias -> 	torch.Size([128]) = 0MB
# inception4.bn2.running_mean -> 	torch.Size([128]) = 0MB
# inception4.bn2.running_var -> 	torch.Size([128]) = 0MB
# inception4.bn2.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception4.conv3.weight -> 	torch.Size([128, 64, 1, 1]) = 0MB
# inception4.conv3.bias -> 	torch.Size([128]) = 0MB
# inception4.bn3.weight -> 	torch.Size([32]) = 0MB
# inception4.bn3.bias -> 	torch.Size([32]) = 0MB
# inception4.bn3.running_mean -> 	torch.Size([32]) = 0MB
# inception4.bn3.running_var -> 	torch.Size([32]) = 0MB
# inception4.bn3.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception4.conv4.weight -> 	torch.Size([128, 32, 5, 5]) = 0MB
# inception4.conv4.bias -> 	torch.Size([128]) = 0MB
# inception4.bn4.weight -> 	torch.Size([128]) = 0MB
# inception4.bn4.bias -> 	torch.Size([128]) = 0MB
# inception4.bn4.running_mean -> 	torch.Size([128]) = 0MB
# inception4.bn4.running_var -> 	torch.Size([128]) = 0MB
# inception4.bn4.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception4.bn5.weight -> 	torch.Size([128]) = 0MB
# inception4.bn5.bias -> 	torch.Size([128]) = 0MB
# inception4.bn5.running_mean -> 	torch.Size([128]) = 0MB
# inception4.bn5.running_var -> 	torch.Size([128]) = 0MB
# inception4.bn5.num_batches_tracked -> 	torch.Size([]) = 0MB
# inception4.bn6.weight -> 	torch.Size([128]) = 0MB
# inception4.bn6.bias -> 	torch.Size([128]) = 0MB
# inception4.bn6.running_mean -> 	torch.Size([128]) = 0MB
# inception4.bn6.running_var -> 	torch.Size([128]) = 0MB
# inception4.bn6.num_batches_tracked -> 	torch.Size([]) = 0MB
# fc1.weight -> 	torch.Size([200, 2048]) = 1MB
# fc1.bias -> 	torch.Size([200]) = 0MB
# conv1.weight -> 	torch.Size([16, 3, 3, 3]) = 0MB
# conv1.bias -> 	torch.Size([16]) = 0MB
# bn1.weight -> 	torch.Size([16]) = 0MB
# bn1.bias -> 	torch.Size([16]) = 0MB
# bn1.running_mean -> 	torch.Size([16]) = 0MB
# bn1.running_var -> 	torch.Size([16]) = 0MB
# bn1.num_batches_tracked -> 	torch.Size([]) = 0MB
# conv2.weight -> 	torch.Size([32, 16, 3, 3]) = 0MB
# conv2.bias -> 	torch.Size([32]) = 0MB
# bn2.weight -> 	torch.Size([32]) = 0MB
# bn2.bias -> 	torch.Size([32]) = 0MB
# bn2.running_mean -> 	torch.Size([32]) = 0MB
# bn2.running_var -> 	torch.Size([32]) = 0MB
# bn2.num_batches_tracked -> 	torch.Size([]) = 0MB
# conv3.weight -> 	torch.Size([64, 32, 3, 3]) = 0MB
# conv3.bias -> 	torch.Size([64]) = 0MB
# bn3.weight -> 	torch.Size([64]) = 0MB
# bn3.bias -> 	torch.Size([64]) = 0MB
# bn3.running_mean -> 	torch.Size([64]) = 0MB
# bn3.running_var -> 	torch.Size([64]) = 0MB
# bn3.num_batches_tracked -> 	torch.Size([]) = 0MB
# conv4.weight -> 	torch.Size([128, 64, 3, 3]) = 0MB
# conv4.bias -> 	torch.Size([128]) = 0MB
# bn4.weight -> 	torch.Size([128]) = 0MB
# bn4.bias -> 	torch.Size([128]) = 0MB
# bn4.running_mean -> 	torch.Size([128]) = 0MB
# bn4.running_var -> 	torch.Size([128]) = 0MB
# bn4.num_batches_tracked -> 	torch.Size([]) = 0MB
# conv5.weight -> 	torch.Size([256, 128, 3, 3]) = 1MB
# conv5.bias -> 	torch.Size([256]) = 0MB
# bn5.weight -> 	torch.Size([256]) = 0MB
# bn5.bias -> 	torch.Size([256]) = 0MB
# bn5.running_mean -> 	torch.Size([256]) = 0MB
# bn5.running_var -> 	torch.Size([256]) = 0MB
# bn5.num_batches_tracked -> 	torch.Size([]) = 0MB
# conv6.weight -> 	torch.Size([512, 256, 3, 3]) = 4MB
# conv6.bias -> 	torch.Size([512]) = 0MB
# bn6.weight -> 	torch.Size([512]) = 0MB
# bn6.bias -> 	torch.Size([512]) = 0MB
# bn6.running_mean -> 	torch.Size([512]) = 0MB
# bn6.running_var -> 	torch.Size([512]) = 0MB
# bn6.num_batches_tracked -> 	torch.Size([]) = 0MB
# lin.weight -> 	torch.Size([1000, 2048]) = 8MB
# lin.bias -> 	torch.Size([1000]) = 0MB
#
# Restored all variables
# No new variables
# Restored /gdrive/My Drive/colab_files/homework1/imagenet_full/004.pt
# Start Epoch:  5
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Tue Oct 30 20:35:11 2018 Train Epoch: 5 [0/1281167 (0%)]	Loss: 2.838190
# Tue Oct 30 20:38:10 2018 Train Epoch: 5 [64000/1281167 (5%)]	Loss: 2.643104
# Tue Oct 30 20:41:08 2018 Train Epoch: 5 [128000/1281167 (10%)]	Loss: 2.686170
# Tue Oct 30 20:44:08 2018 Train Epoch: 5 [192000/1281167 (15%)]	Loss: 2.714294
# Tue Oct 30 20:47:08 2018 Train Epoch: 5 [256000/1281167 (20%)]	Loss: 2.761017
# Tue Oct 30 20:50:05 2018 Train Epoch: 5 [320000/1281167 (25%)]	Loss: 3.062316
# Tue Oct 30 20:53:06 2018 Train Epoch: 5 [384000/1281167 (30%)]	Loss: 2.982330
# Tue Oct 30 20:56:07 2018 Train Epoch: 5 [448000/1281167 (35%)]	Loss: 3.151167
# Tue Oct 30 20:59:05 2018 Train Epoch: 5 [512000/1281167 (40%)]	Loss: 3.698591
# Tue Oct 30 21:02:04 2018 Train Epoch: 5 [576000/1281167 (45%)]	Loss: 3.128415
# Tue Oct 30 21:05:04 2018 Train Epoch: 5 [640000/1281167 (50%)]	Loss: 2.551825
# Tue Oct 30 21:08:03 2018 Train Epoch: 5 [704000/1281167 (55%)]	Loss: 2.676398
# Tue Oct 30 21:11:02 2018 Train Epoch: 5 [768000/1281167 (60%)]	Loss: 2.893399
# Tue Oct 30 21:14:00 2018 Train Epoch: 5 [832000/1281167 (65%)]	Loss: 2.919271
# Tue Oct 30 22:25:12 2018 Train Epoch: 6 [1024000/1281167 (80%)]	Loss: 2.499218
# Tue Oct 30 22:28:03 2018 Train Epoch: 6 [1088000/1281167 (85%)]	Loss: 3.603374
# Tue Oct 30 22:31:00 2018 Train Epoch: 6 [1152000/1281167 (90%)]	Loss: 2.931722
# Tue Oct 30 22:33:54 2018 Train Epoch: 6 [1216000/1281167 (95%)]	Loss: 3.090721
# Tue Oct 30 22:36:46 2018 Train Epoch: 6 [1280000/1281167 (100%)]	Loss: 3.603164
#
# Test set: Average loss: 3.4019, Accuracy: 15149/50000 (30%)
#
# save checkpoint
# Saved /gdrive/My Drive/colab_files/homework1/imagenet_full/006.pt
#
# saving model?
# saving log data:  {'train_loss': [4.39100306772127, 3.376638364825217, 3.1451884585128593, 3.040582446191175, 2.978509414135871, 2.9373717507530483, 2.9079868138816023, 2.886060114465183], 'test_loss': [3.883790785179138, 3.596280732460022, 3.547088831329346, 3.478510228919983, 3.335424249305725, 3.465609636955261, 3.343398171234131, 3.4018845848464965], 'test_accuracy': [23.268, 27.162, 27.986, 29.026, 31.242, 29.354, 31.05, 30.298]}
# Tue Oct 30 22:40:27 2018 Train Epoch: 7 [0/1281167 (0%)]	Loss: 2.607858
# Tue Oct 30 22:43:31 2018 Train Epoch: 7 [64000/1281167 (5%)]	Loss: 2.683415
# Tue Oct 30 22:46:25 2018 Train Epoch: 7 [128000/1281167 (10%)]	Loss: 2.919398
# Tue Oct 30 22:49:21 2018 Train Epoch: 7 [192000/1281167 (15%)]	Loss: 2.998484
# Tue Oct 30 22:52:14 2018 Train Epoch: 7 [256000/1281167 (20%)]	Loss: 2.976186
# Tue Oct 30 22:55:10 2018 Train Epoch: 7 [320000/1281167 (25%)]	Loss: 2.903478
# Process Process-10:
# Process Process-9:
# Interrupted
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 106, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 106, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "<ipython-input-11-e8c5fac7a986>", line 18, in __getitem__
#     img = self.transform(img)
#   File "<ipython-input-11-e8c5fac7a986>", line 18, in __getitem__
#     img = self.transform(img)
#   File "/usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py", line 49, in __call__
#     img = t(img)
#   File "/usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py", line 175, in __call__
#     return F.resize(img, self.size, self.interpolation)
#   File "/usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional.py", line 206, in resize
#     return img.resize(size[::-1], interpolation)
#   File "/usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py", line 49, in __call__
#     img = t(img)
#   File "/usr/local/lib/python3.6/dist-packages/PIL/Image.py", line 1556, in resize
#     self.pyaccess = None
#   File "/usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py", line 175, in __call__
#     return F.resize(img, self.size, self.interpolation)
#   File "/usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional.py", line 206, in resize
#     return img.resize(size[::-1], interpolation)
#   File "/usr/local/lib/python3.6/dist-packages/PIL/Image.py", line 1556, in resize
#     self.pyaccess = None
# KeyboardInterrupt
# KeyboardInterrupt
# Saved /gdrive/My Drive/colab_files/homework1/imagenet_full/checkpoints/007.pt

# %%
MODEL_PATH = BASE_PATH + 'imagenet_full/'
LOG_PATH = MODEL_PATH + 'log.pkl'

log_data = pt_util.read_log(LOG_PATH)

epochs = np.arange(len(log_data['train_loss']))
plot_loss(epochs, log_data['train_loss'], log_data['test_loss'], 'Epoch vs Loss', 'Epochs', 'Loss')
pt_util.plot(epochs, log_data['test_accuracy'], 'Epoch vs Test Accuracy', 'Epochs', 'Accuracy')

# %% [markdown]
# # Part 7: Short answer questions
# Please answer these questions, and put the answers in a file called homework1_python.pdf in your repository.
#
# # Tiny ImageNet
# 1. What design that you tried worked the best? This includes things like network design, learning rate, batch size, number of epochs, and other optimization parameters, data augmentation etc. What was the final train loss? Test loss? Test Accuracy? Provide the plots for train loss, test loss, and test accuracy.
# 2. What design worked the worst (but still performed better than random chance)? Provide all the same information as question 1.
# 3. Why do you think the best one worked well and the worst one worked poorly.
#
#
# # Full ImageNet
# 1. What design that you tried worked the best? How many epochs were you able to run it for? Provide the same information from Tiny ImageNet question 1.
# 2. Were you able to use larger/deeper networks on Full ImageNet than you used on Tiny ImageNet and increase accuracy? If so, why? If not, why not?
# 3. The real ImageNet dataset has significantly larger images. How would you change your network design if the images were twice as large? How about smaller than Tiny ImageNet (32x32)? How do you think your accuracy would change? This is open-ended, but we want a more thought-out answer than "I'd resize the images" or "I'd do a larger pooling stride." You don't have to write code to test your hypothesis.
#
# Additionally, download your .ipynb and put it in your repository and name it homework1_colab.ipynb
